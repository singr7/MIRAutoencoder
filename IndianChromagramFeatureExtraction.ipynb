# %% [markdown]
# <a href="https://colab.research.google.com/github/singr7/MIRAutoencoder/blob/master/IndianChromagramFeatureExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Music Feature extraction using librosa

# %% [markdown]
# In music, the term chromafeature or chromagram closely relates to the twelve different pitch classes.Chroma-based features, which are also referred to as "pitch class profiles", are a powerful tool for analyzing music whose pitches can be meaningfully categorized(often into twelve categories) and whose tuning approximates to the equal-tempered scale. One main property of chroma features is that they capture harmonic and melodic characteristics of music, while being robust to changes in timbre and instrumentation.Chroma features aim at representing the harmonic content(eg:keys,chords) of a short-time window of audio.

# %%
#!npx degit Jainu-s/urldata/al -f
#load the indian dataset
# !npx degit indian-music-arch/IndianSongsDataset/data -f
# Out:
# npx: installed 1 in 3.382s
# > destination directory is not empty. Using --force, continuing
# > cloned indian-music-arch/IndianSongsDataset#HEAD

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
songs = []
for root, dirs, files in os.walk("/content"):
    
    if 'config' not in root and 'sample_data' not in root and 'drive'  not in root :
      print(root)
      for file in files:
        if file.endswith(".mp3"):
          songs.append(os.path.join(root, file))
# Out:
# /content
# /content/bengali
# /content/bengali/normal
# /content/bengali/old
# /content/telugu
# /content/telugu/devotional
# /content/telugu/normal
# /content/kannada
# /content/kannada/devotional
# /content/kannada/normal
# /content/gujarati
# /content/gujarati/classical
# /content/gujarati/normal
# /content/tamil
# /content/tamil/classical
# /content/tamil/normal
# /content/tamil/kuthu-weird-songs
# /content/marathi
# /content/marathi/classical
# /content/marathi/normal
# /content/malayalam
# /content/malayalam/devotional
# /content/malayalam/normal
# /content/malayalam/old
# /content/punjabi
# /content/punjabi/classical
# /content/punjabi/normal
# /content/hindi
# /content/hindi/classical
# /content/hindi/acoustic
# /content/hindi/devotional
# /content/hindi/normal
# /content/hindi/old

# %%
len(songs)
# Out:
# 2271

# %%
import librosa
import librosa.display
import scipy.ndimage
import numpy as np
from pylab import plot, show, figure, imshow
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
print(songs[10])
print(songs[10].split('/')[-1].replace('.mp3',''))
# Out:
# /content/bengali/normal/Ishq Wala Love.mp3
# Ishq Wala Love

# %% [markdown]
# To check for a single song

# %%
y,sr = librosa.load(songs[10], duration = 20, sr=16000)
chromagram = librosa.feature.chroma_stft(y=y, sr=sr,n_fft=2048, hop_length=800, n_chroma=12)
chromagram = chromagram[:, :-1].astype('float32')
print(chromagram.shape,sr)

#np.save("./MusicResearchColabNB/Test1.npy", log_melspectrogram_new)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (12, 400) 16000

# %%
l_count=0
# Some corrupt songs need to be removed. so some of this can fail.. For example song at 3960 099134.mp3 ,  , 3960+894=4854 108925.mp3 , 7178etc...
# 4854+2122= 6976
# the base_dir is always commented else it can override the existing files unintentionally.
#base_dir = /content/drive/My Drive//MusicResearchColabNB/MelFeatures

base_dir = "/content/drive/My Drive/MusicResearch/vajra/ChromaFeatures"

for song in songs:
  l_count=l_count+1
  s= song.split('/')[-1].replace('.mp3','').replace('\'','')
  s_new = ''.join(s.split('(')[0].split()) +'.npy'
  if '-' in s_new:
    s_new = s_new.split('-')[0]+'.npy'
  print(l_count, song.split('/')[-1], s_new)

  y,sr = librosa.load(song, duration = 20, sr=16000)
  chromagram = librosa.feature.chroma_stft(y=y, sr=sr,n_fft=2048, hop_length=800, n_chroma=12)
  chromagram = chromagram[:, :-1].astype('float32')
  chromagram_arr = np.array(chromagram)
  #np_file_nm = song.split('/')[-1].replace('.mp3','.npy')
  np.save(base_dir+"/Indian_chroma_numpy/"+s_new,chromagram_arr )
# Out:
# 1 Ay Hairathe (From "Guru").mp3 AyHairathe.npy
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 2 Megher Palok.mp3 MegherPalok.npy
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 3 Bin Tere (From "I Hate Luv Storys").mp3 BinTere.npy
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 4 Kabhi Alvida Naa Kehna.mp3 KabhiAlvidaNaaKehna.npy
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
# read a npy and extract its first input...
import numpy as np
y_sample = np.load('/content/drive/My Drive/MusicResearch/vajra/ChromaFeatures/Western_chroma_numpy/154414.npy')
y_sample.shape
# Out:
# (12, 400)

# %%
# To plot a single loaded mp3 file as is
#song =??
#y_sample,sr = librosa.load(song, duration = 20, sr=16000)
#plt.figure(figsize=(15, 5))
#librosa.display.waveplot(y_sample, sr, alpha=0.8)

# %%
# This block is when you just want to plot the log_melspectrogram for a single file
#
#single_log_melspectrogram =??
#plt.figure(figsize=(25,10))
#librosa.display.specshow(single_log_melspectrogram
#                         , x_axis ='time'
#                         , y_axis = 'mel'
#                         , sr = sr)
#plt.colorbar(format="%+2.f")
#plt.show()
